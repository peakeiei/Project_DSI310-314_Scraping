# %%
# !pip install transformers torch
# !pip install sentencepiece

# %%
from dsmlibrary.datanode import DataNode
from dsmlibrary.datanode import DataNode
import json
from tqdm.auto import tqdm
import pandas as pd

# %%
dir_file_id = 100

# %%
datanode = DataNode()
# Out:
# Init DataNode sucessful!

# %%
meta, fp = datanode.get_file(datanode.get_file_id(directory_id=dir_file_id, name='Haribo_cleaning_update.csv'))
meta
# Out:
# {'owner': 'thittipat',
#  'human_size': '7.59 KB',
#  'name': 'Haribo_cleaning_update.csv',
#  'description': '-',
#  'directory': 100,
#  'path': 'thittipat/DSI310-20/raw/Haribo_cleaning_update.csv'}

# %%
keep = pd.read_csv(fp)

# %%
keep
# Out:
#                                            ชื่อสินค้า  \
# 0                                     Haribo ผลไม้รวม
# 1                                     Haribo ผลไม้รวม
# 2       Haribo Goldbears Happy Cola Happy Mix Berries
# 3       Haribo Goldbears Happy Cola Happy Mix Berries
# 4                                     Haribo ผลไม้รวม
# 5                               Haribo  Berries Jelly
# 6                         Haribo Happy Grapes รสองุ่น
# 7                                 Haribo Salino Jelly
# 8   Haribo เยอรมัน Grape Fruity Goldbear Peach Col...
# 9                         Haribo Happy Cherries Jelly
# 10  Haribo เยอรมัน Grape Fruity Goldbear Peach Col...
# 11                        Haribo Happy Grapes รสองุ่น
# 12                                       Haribo Worms
# 13                                    Haribo ผลไม้รวม
# 14                                  Haribo Pico Balla
# 15                                       ทุกรส Haribo
# ...

# %%
df = pd.DataFrame(keep)
df
# Out:
#                                            ชื่อสินค้า  \
# 0                                     Haribo ผลไม้รวม
# 1                                     Haribo ผลไม้รวม
# 2       Haribo Goldbears Happy Cola Happy Mix Berries
# 3       Haribo Goldbears Happy Cola Happy Mix Berries
# 4                                     Haribo ผลไม้รวม
# 5                               Haribo  Berries Jelly
# 6                         Haribo Happy Grapes รสองุ่น
# 7                                 Haribo Salino Jelly
# 8   Haribo เยอรมัน Grape Fruity Goldbear Peach Col...
# 9                         Haribo Happy Cherries Jelly
# 10  Haribo เยอรมัน Grape Fruity Goldbear Peach Col...
# 11                        Haribo Happy Grapes รสองุ่น
# 12                                       Haribo Worms
# 13                                    Haribo ผลไม้รวม
# 14                                  Haribo Pico Balla
# 15                                       ทุกรส Haribo
# ...

# %%
datanode.write(df=df, directory=dir_file_id, name="Haribo", profiling=True, lineage=[datanode.get_file_id(directory_id=dir_file_id, name='Haribo_cleaning_update.csv')])
# Out:
# File Haribo.parquet alrady exists, do you want to replace y/n :  y
# {'sucess': True,
#  'file_id': 202,
#  'path': 'thittipat/DSI310-20/raw/Haribo.parquet',
#  'lineage': True}
